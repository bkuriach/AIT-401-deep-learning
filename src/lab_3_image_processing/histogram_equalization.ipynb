# %%
import cv2
print(cv2.__version__)
import numpy as np
from matplotlib import pyplot as plt
# Out:
# 4.8.0

# %% [markdown]
# ### Histogram Equalization

# %% [markdown]
# Histogram equalization is a method in image processing of contrast adjustment using the image’s histogram. It aims to distribute the intensity values of the image more uniformly, so that the image utilizes the full range of possible values from 0 (black) to 255 (white). This can enhance the contrast and details of the image.

# %%
img = cv2.imread('albert-einstein.jpg',0) # load image in grayscale mode
equ = cv2.equalizeHist(img) # apply histogram equalization
cv2.imwrite('equalized_image.jpg',equ) # save the result

# plot the original and equalized histograms
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.hist(equ.flatten(),256,[0,256], color = 'b')
plt.xlim([0,256])
plt.legend(('Original','Equalized'), loc = 'upper left')
plt.show()

# %%
plt.imshow(img, cmap='gray')

# %%
plt.imshow(equ, cmap='gray')
