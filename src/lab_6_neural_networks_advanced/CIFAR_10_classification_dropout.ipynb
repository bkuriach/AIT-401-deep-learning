# %%
import os
import time
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
import tensorflow_datasets as tfds
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras import (
    models,
    layers,
) 
from matplotlib import pyplot as plt
import numpy as np
import random
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt

# %%
cifar_10_labels = {
    0: 'airplane',
    1: 'automobile',
    2: 'bird',
    3: 'cat',
    4: 'deer',
    5: 'dog',
    6: 'frog',
    7: 'horse',
    8: 'ship',
    9: 'truck'
    }

model_directory = 'models'

# %%
class RandomIntegers():
    def __init__(self):
        pass
    
    def generate(self, n, length):
        # Generate n unique random integers between 0 and length
        random_integers = random.sample(range(length), n)
        
        return random_integers

# %% [markdown]
# #### CIFAR-10
# ###### CIFAR-10 dataset consists of 60000 32×32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.

# %%
# Load the CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train/255
x_test = x_test/255

# %% [markdown]
# ### Plot dataset

# %%
def display_images():
    random_integers = RandomIntegers().generate(9, len(x_train))
    plt.figure(figsize=(6, 8))
    counter = 0
    for i in random_integers:
        # define subplot
        plt.subplot(330 + 1 + counter)
        counter += 1
        # plot raw pixel data
        plt.imshow(x_train[i])
        plt.title(cifar_10_labels[y_train[i][0]])
    # show the figure
    plt.show()
display_images()

# %% [markdown]
# ### Dropout
#
# Add details here

# %% [markdown]
# ### Build Model

# %%
model = tensorflow.keras.models.Sequential([
    
    tensorflow.keras.layers.Flatten(input_shape=(32, 32, 3)),
    tensorflow.keras.layers.Dense(128, 
                                  activation='relu', 
                                 ),
    tensorflow.keras.layers.Dense(32, activation='relu'),
    tensorflow.keras.layers.Dense(10, 
                                  activation='softmax',
                                 )
])

# %%
model_with_dropout = tensorflow.keras.models.Sequential([
    
    tensorflow.keras.layers.Flatten(input_shape=(32, 32, 3)),
    tensorflow.keras.layers.Dense(128, 
                                  activation='relu', 
                                 ),
    tensorflow.keras.layers.Dropout(0.2),
    tensorflow.keras.layers.Dense(32, activation='relu'),
    tensorflow.keras.layers.Dropout(0.2),
    tensorflow.keras.layers.Dense(10, 
                                  activation='softmax',
                                 )
])

# %% [markdown]
# ### Compiling the model

# %%
# model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.compile(
    optimizer=tf.keras.optimizers.Adam(0.001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.

# %%
model_with_dropout.compile(
    optimizer=tf.keras.optimizers.Adam(0.001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.

# %% [markdown]
# #### Model Training

# %%
start_time = time.time()
history = model.fit(x_train,
                    y_train,
                    epochs=25,
                    batch_size=512,
                    validation_data=(x_test, y_test))
end_time = time.time()
total_time = end_time - start_time

print("Time taken for training: ", total_time, " seconds")
# Out:
# Epoch 1/25
# /Users/binilkuriachan/anaconda3/envs/ail-411-env/lib/python3.9/site-packages/keras/src/backend.py:5714: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 98/98 [==============================] - 1s 11ms/step - loss: 2.5296 - sparse_categorical_accuracy: 0.2224 - val_loss: 2.0018 - val_sparse_categorical_accuracy: 0.2731
# Epoch 2/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.9643 - sparse_categorical_accuracy: 0.2994 - val_loss: 1.9219 - val_sparse_categorical_accuracy: 0.3111
# Epoch 3/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.9113 - sparse_categorical_accuracy: 0.3197 - val_loss: 1.9598 - val_sparse_categorical_accuracy: 0.2925
# Epoch 4/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.8835 - sparse_categorical_accuracy: 0.3325 - val_loss: 1.8486 - val_sparse_categorical_accuracy: 0.3507
# Epoch 5/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.8467 - sparse_categorical_accuracy: 0.3484 - val_loss: 1.8494 - val_sparse_categorical_accuracy: 0.3328
# Epoch 6/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.8390 - sparse_categorical_accuracy: 0.3486 - val_loss: 1.8397 - val_sparse_categorical_accuracy: 0.3454
# Epoch 7/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.8193 - sparse_categorical_accuracy: 0.3604 - val_loss: 1.8077 - val_sparse_categorical_accuracy: 0.3649
# Epoch 8/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.8095 - sparse_categorical_accuracy: 0.3625 - val_loss: 1.8213 - val_sparse_categorical_accuracy: 0.3560
# Epoch 9/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.8034 - sparse_categorical_accuracy: 0.3667 - val_loss: 1.8131 - val_sparse_categorical_accuracy: 0.3552
# Epoch 10/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7926 - sparse_categorical_accuracy: 0.3691 - val_loss: 1.7871 - val_sparse_categorical_accuracy: 0.3731
# Epoch 11/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7827 - sparse_categorical_accuracy: 0.3777 - val_loss: 1.8555 - val_sparse_categorical_accuracy: 0.3383
# Epoch 12/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7842 - sparse_categorical_accuracy: 0.3739 - val_loss: 1.7865 - val_sparse_categorical_accuracy: 0.3740
# Epoch 13/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7789 - sparse_categorical_accuracy: 0.3746 - val_loss: 1.7753 - val_sparse_categorical_accuracy: 0.3741
# Epoch 14/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7692 - sparse_categorical_accuracy: 0.3820 - val_loss: 1.7779 - val_sparse_categorical_accuracy: 0.3714
# Epoch 15/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7620 - sparse_categorical_accuracy: 0.3852 - val_loss: 1.7685 - val_sparse_categorical_accuracy: 0.3860
# Epoch 16/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7648 - sparse_categorical_accuracy: 0.3838 - val_loss: 1.7686 - val_sparse_categorical_accuracy: 0.3772
# Epoch 17/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7555 - sparse_categorical_accuracy: 0.3889 - val_loss: 1.7643 - val_sparse_categorical_accuracy: 0.3762
# Epoch 18/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7538 - sparse_categorical_accuracy: 0.3896 - val_loss: 1.7619 - val_sparse_categorical_accuracy: 0.3791
# Epoch 19/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7564 - sparse_categorical_accuracy: 0.3880 - val_loss: 1.7748 - val_sparse_categorical_accuracy: 0.3758
# Epoch 20/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7521 - sparse_categorical_accuracy: 0.3877 - val_loss: 1.7571 - val_sparse_categorical_accuracy: 0.3873
# Epoch 21/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7485 - sparse_categorical_accuracy: 0.3901 - val_loss: 1.7894 - val_sparse_categorical_accuracy: 0.3676
# Epoch 22/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7473 - sparse_categorical_accuracy: 0.3905 - val_loss: 1.7494 - val_sparse_categorical_accuracy: 0.3892
# Epoch 23/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7511 - sparse_categorical_accuracy: 0.3901 - val_loss: 1.7606 - val_sparse_categorical_accuracy: 0.3861
# Epoch 24/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7484 - sparse_categorical_accuracy: 0.3892 - val_loss: 1.7518 - val_sparse_categorical_accuracy: 0.3866
# Epoch 25/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7430 - sparse_categorical_accuracy: 0.3903 - val_loss: 1.7639 - val_sparse_categorical_accuracy: 0.3776
# Time taken for training:  19.10897994041443  seconds

# %%
start_time = time.time()
history_dropout = model_with_dropout.fit(x_train,
                    y_train,
                    epochs=25,
                    batch_size=512,
                    validation_data=(x_test, y_test))
end_time = time.time()
total_time = end_time - start_time

print("Time taken for training (Model with dropout): ", total_time, " seconds")
# Out:
# Epoch 1/25
# 98/98 [==============================] - 1s 10ms/step - loss: 7.0021 - sparse_categorical_accuracy: 0.1257 - val_loss: 2.2216 - val_sparse_categorical_accuracy: 0.2604
# Epoch 2/25
# 98/98 [==============================] - 1s 7ms/step - loss: 5.4524 - sparse_categorical_accuracy: 0.1688 - val_loss: 2.2738 - val_sparse_categorical_accuracy: 0.2788
# Epoch 3/25
# 98/98 [==============================] - 1s 7ms/step - loss: 4.1347 - sparse_categorical_accuracy: 0.2033 - val_loss: 2.1194 - val_sparse_categorical_accuracy: 0.3158
# Epoch 4/25
# 98/98 [==============================] - 1s 7ms/step - loss: 3.2955 - sparse_categorical_accuracy: 0.2228 - val_loss: 1.8924 - val_sparse_categorical_accuracy: 0.3371
# Epoch 5/25
# 98/98 [==============================] - 1s 7ms/step - loss: 2.7438 - sparse_categorical_accuracy: 0.2365 - val_loss: 1.8487 - val_sparse_categorical_accuracy: 0.3538
# Epoch 6/25
# 98/98 [==============================] - 1s 7ms/step - loss: 2.3899 - sparse_categorical_accuracy: 0.2576 - val_loss: 1.8323 - val_sparse_categorical_accuracy: 0.3499
# Epoch 7/25
# 98/98 [==============================] - 1s 7ms/step - loss: 2.1811 - sparse_categorical_accuracy: 0.2725 - val_loss: 1.8345 - val_sparse_categorical_accuracy: 0.3459
# Epoch 8/25
# 98/98 [==============================] - 1s 7ms/step - loss: 2.0355 - sparse_categorical_accuracy: 0.2896 - val_loss: 1.8150 - val_sparse_categorical_accuracy: 0.3521
# Epoch 9/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.9735 - sparse_categorical_accuracy: 0.3040 - val_loss: 1.8174 - val_sparse_categorical_accuracy: 0.3569
# Epoch 10/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.9363 - sparse_categorical_accuracy: 0.3122 - val_loss: 1.8329 - val_sparse_categorical_accuracy: 0.3425
# Epoch 11/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.9010 - sparse_categorical_accuracy: 0.3259 - val_loss: 1.8067 - val_sparse_categorical_accuracy: 0.3586
# Epoch 12/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.8950 - sparse_categorical_accuracy: 0.3260 - val_loss: 1.8019 - val_sparse_categorical_accuracy: 0.3635
# Epoch 13/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.8809 - sparse_categorical_accuracy: 0.3334 - val_loss: 1.8121 - val_sparse_categorical_accuracy: 0.3581
# Epoch 14/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.8802 - sparse_categorical_accuracy: 0.3306 - val_loss: 1.8155 - val_sparse_categorical_accuracy: 0.3666
# Epoch 15/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.8843 - sparse_categorical_accuracy: 0.3332 - val_loss: 1.7965 - val_sparse_categorical_accuracy: 0.3695
# Epoch 16/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.8730 - sparse_categorical_accuracy: 0.3370 - val_loss: 1.8137 - val_sparse_categorical_accuracy: 0.3615
# Epoch 17/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.8716 - sparse_categorical_accuracy: 0.3349 - val_loss: 1.7935 - val_sparse_categorical_accuracy: 0.3705
# Epoch 18/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.8658 - sparse_categorical_accuracy: 0.3379 - val_loss: 1.7882 - val_sparse_categorical_accuracy: 0.3731
# Epoch 19/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.8640 - sparse_categorical_accuracy: 0.3379 - val_loss: 1.7942 - val_sparse_categorical_accuracy: 0.3670
# Epoch 20/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.8664 - sparse_categorical_accuracy: 0.3389 - val_loss: 1.8017 - val_sparse_categorical_accuracy: 0.3541
# Epoch 21/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.8648 - sparse_categorical_accuracy: 0.3366 - val_loss: 1.8109 - val_sparse_categorical_accuracy: 0.3576
# Epoch 22/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.8555 - sparse_categorical_accuracy: 0.3442 - val_loss: 1.7884 - val_sparse_categorical_accuracy: 0.3733
# Epoch 23/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.8628 - sparse_categorical_accuracy: 0.3409 - val_loss: 1.7992 - val_sparse_categorical_accuracy: 0.3630
# Epoch 24/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.8609 - sparse_categorical_accuracy: 0.3391 - val_loss: 1.8040 - val_sparse_categorical_accuracy: 0.3584
# Epoch 25/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.8643 - sparse_categorical_accuracy: 0.3366 - val_loss: 1.7883 - val_sparse_categorical_accuracy: 0.3680
# Time taken for training (Model with dropout):  19.29431700706482  seconds

# %% [markdown]
# #### Plot Accuracy

# %%
# Plot the accuracy from the training history
plt.plot(history.history['sparse_categorical_accuracy'])
plt.plot(history.history['val_sparse_categorical_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot the accuracy from the training history
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot the accuracy from the training history
plt.plot(history_dropout.history['sparse_categorical_accuracy'])
plt.plot(history_dropout.history['val_sparse_categorical_accuracy'])
plt.title('Model Accuracy (Dropout)')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot the accuracy from the training history
plt.plot(history_dropout.history['loss'])
plt.plot(history_dropout.history['val_loss'])
plt.title('Loss (Dropout)')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# #### Save model

# %%
if not os.path.exists(model_directory):
    os.makedirs(model_directory)
model_path = os.path.join(model_directory,"model_nn.h5")
model.save(model_path)

model_path_dropout = os.path.join(model_directory,"model_nn_dropout.h5")
model_with_dropout.save(model_path_dropout)

# %% [markdown]
# #### Load Model

# %%
# Load the saved model from a file
loaded_model = tf.keras.models.load_model(model_path)
loaded_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 3072)              0
#
#  dense (Dense)               (None, 128)               393344
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 394634 (1.51 MB)
# Trainable params: 394634 (1.51 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Load the saved model from a file
model_path = os.path.join(model_directory,"model_nn_dropout.h5")
loaded_model_dropout = tf.keras.models.load_model(model_path_dropout)
loaded_model_dropout.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 3072)              0
#
#  dense_3 (Dense)             (None, 128)               393344
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_4 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 394634 (1.51 MB)
# Trainable params: 394634 (1.51 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #### Predict

# %%
# Get the true labels and predicted labels for the test dataset
true_labels = np.concatenate([y for x, y in zip(x_test,y_test)], axis=0)
predicted_labels = np.argmax(model.predict(x_test), axis=-1)
# Out:
# 313/313 [==============================] - 0s 1ms/step

# %%
# Get the true labels and predicted labels for the test dataset
true_labels = np.concatenate([y for x, y in zip(x_test,y_test)], axis=0)
predicted_labels_dropout = np.argmax(loaded_model_dropout.predict(x_test), axis=-1)
# Out:
# 313/313 [==============================] - 0s 1ms/step

# %% [markdown]
# #### Confusion Matrix

# %%
# Generate the confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)

# Plot the confusion matrix
plt.imshow(cm, cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.xticks(np.arange(10))
plt.yticks(np.arange(10))
plt.show()

# %%
# Generate the confusion matrix
cm = confusion_matrix(true_labels, predicted_labels_dropout)

# Plot the confusion matrix
plt.imshow(cm, cmap=plt.cm.Blues)
plt.title('Confusion Matrix (Dropout)')
plt.colorbar()
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.xticks(np.arange(10))
plt.yticks(np.arange(10))
plt.show()

# %% [markdown]
# #### Classification Report

# %%
# Generate the classification report
report = classification_report(true_labels, predicted_labels, target_names=cifar_10_labels.values(),)

# Print the classification report
print(report)
# Out:
#               precision    recall  f1-score   support
#
#     airplane       0.38      0.53      0.44      1000
#   automobile       0.51      0.39      0.45      1000
#         bird       0.29      0.01      0.03      1000
#          cat       0.28      0.18      0.22      1000
#         deer       0.29      0.43      0.34      1000
#          dog       0.27      0.39      0.32      1000
#         frog       0.33      0.62      0.43      1000
#        horse       0.61      0.23      0.34      1000
#         ship       0.42      0.56      0.48      1000
#        truck       0.53      0.33      0.41      1000
#
#     accuracy                           0.37     10000
#    macro avg       0.39      0.37      0.35     10000
# weighted avg       0.39      0.37      0.35     10000

# %%
# Generate the classification report
report = classification_report(true_labels, predicted_labels_dropout, target_names=cifar_10_labels.values(),)

# Print the classification report
print(report)
# Out:
#               precision    recall  f1-score   support
#
#     airplane       0.40      0.49      0.44      1000
#   automobile       0.46      0.43      0.44      1000
#         bird       0.29      0.20      0.24      1000
#          cat       0.22      0.43      0.29      1000
#         deer       0.48      0.07      0.13      1000
#          dog       0.42      0.23      0.30      1000
#         frog       0.37      0.46      0.41      1000
#        horse       0.38      0.49      0.43      1000
#         ship       0.49      0.37      0.42      1000
#        truck       0.43      0.51      0.47      1000
#
#     accuracy                           0.37     10000
#    macro avg       0.39      0.37      0.36     10000
# weighted avg       0.39      0.37      0.36     10000

# %% [markdown]
# #### In multi-class classification problems, macro-average and micro-average are two commonly used methods to calculate precision, recall, and accuracy.
#
# Micro-average calculates the metrics globally by counting the total true positives, false negatives, and false positives across all classes. Micro-average is useful when you want to weight each instance or prediction equally, regardless of the class.
#
# Macro-average calculates the metrics for each class separately and then takes the average across all classes. Macro-average is useful when you want to weight each class equally, regardless of the number of instances or predictions in each class.
#
# Here's a brief explanation of the differences between micro-average and macro-average for precision, recall, and accuracy:
# Micro-average precision, recall, and accuracy are calculated by counting the total true positives, false negatives, and false positives across all classes and then calculating the precision, recall, and accuracy from those counts. Micro-average gives equal weight to each instance or prediction, regardless of the class.
#
# * Macro-average precision, recall, and accuracy are calculated by calculating the precision, recall, and accuracy for each class separately and then taking the average across all classes.
# * Macro-average gives equal weight to each class, regardless of the number of instances or predictions in each class.
