# %%
import os
import time
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
import tensorflow_datasets as tfds
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras import (
    models,
    layers,
) 
from matplotlib import pyplot as plt
import numpy as np
import random
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt

# %%
cifar_10_labels = {
    0: 'airplane',
    1: 'automobile',
    2: 'bird',
    3: 'cat',
    4: 'deer',
    5: 'dog',
    6: 'frog',
    7: 'horse',
    8: 'ship',
    9: 'truck'
    }

model_directory = 'models'

# %%
class RandomIntegers():
    def __init__(self):
        pass
    
    def generate(self, n, length):
        # Generate n unique random integers between 0 and length
        random_integers = random.sample(range(length), n)
        
        return random_integers

# %% [markdown]
# #### CIFAR-10
# ###### CIFAR-10 dataset consists of 60000 32×32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.

# %%
# Load the CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train/255
x_test = x_test/255

# %% [markdown]
# ### Plot dataset

# %%
def display_images():
    random_integers = RandomIntegers().generate(9, len(x_train))
    plt.figure(figsize=(6, 8))
    counter = 0
    for i in random_integers:
        # define subplot
        plt.subplot(330 + 1 + counter)
        counter += 1
        # plot raw pixel data
        plt.imshow(x_train[i])
        plt.title(cifar_10_labels[y_train[i][0]])
    # show the figure
    plt.show()
display_images()

# %% [markdown]
# ### Regularization
#
# Add details here

# %% [markdown]
# ### Build Model

# %%
model = tensorflow.keras.models.Sequential([
    
    tensorflow.keras.layers.Flatten(input_shape=(32, 32, 3)),
    tensorflow.keras.layers.Dense(128, 
                                  activation='relu', 
                                 ),
    tensorflow.keras.layers.Dense(32, activation='relu'),
    tensorflow.keras.layers.Dense(10, 
                                  activation='softmax',
                                 )
])

# %%
model_l2 = tensorflow.keras.models.Sequential([
    
    tensorflow.keras.layers.Flatten(input_shape=(32, 32, 3)),
    tensorflow.keras.layers.Dense(
                                  128, 
                                  activation='relu', 
                                  kernel_regularizer=tensorflow.keras.regularizers.l2(0.01),
                                 ),
    tensorflow.keras.layers.Dense(
                                  32, 
                                  activation='relu',
                                  kernel_regularizer=tensorflow.keras.regularizers.l2(0.01),
    ),
    tensorflow.keras.layers.Dense(10, 
                                  activation='softmax',
                                 )
])

# %% [markdown]
# ### Compiling the model

# %%
# model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.compile(
    optimizer=tf.keras.optimizers.Adam(0.001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.

# %%
model_l2.compile(
    optimizer=tf.keras.optimizers.Adam(0.001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.

# %% [markdown]
# #### Model Training

# %%
start_time = time.time()
history = model.fit(x_train,
                    y_train,
                    epochs=25,
                    batch_size=512,
                    validation_data=(x_test, y_test))
end_time = time.time()
total_time = end_time - start_time

print("Time taken for training: ", total_time, " seconds")
# Out:
# Epoch 1/25
# /Users/binilkuriachan/anaconda3/envs/ail-411-env/lib/python3.9/site-packages/keras/src/backend.py:5714: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 98/98 [==============================] - 3s 21ms/step - loss: 2.9388 - sparse_categorical_accuracy: 0.1527 - val_loss: 2.2524 - val_sparse_categorical_accuracy: 0.1858
# Epoch 2/25
# 98/98 [==============================] - 1s 13ms/step - loss: 2.1794 - sparse_categorical_accuracy: 0.2003 - val_loss: 2.1715 - val_sparse_categorical_accuracy: 0.2170
# Epoch 3/25
# 98/98 [==============================] - 1s 11ms/step - loss: 2.1505 - sparse_categorical_accuracy: 0.2239 - val_loss: 2.1126 - val_sparse_categorical_accuracy: 0.2323
# Epoch 4/25
# 98/98 [==============================] - 1s 14ms/step - loss: 2.2028 - sparse_categorical_accuracy: 0.2203 - val_loss: 2.1847 - val_sparse_categorical_accuracy: 0.2280
# Epoch 5/25
# 98/98 [==============================] - 1s 13ms/step - loss: 2.1741 - sparse_categorical_accuracy: 0.2346 - val_loss: 2.1862 - val_sparse_categorical_accuracy: 0.2312
# Epoch 6/25
# 98/98 [==============================] - 1s 11ms/step - loss: 2.1502 - sparse_categorical_accuracy: 0.2477 - val_loss: 2.2749 - val_sparse_categorical_accuracy: 0.2230
# Epoch 7/25
# 98/98 [==============================] - 1s 11ms/step - loss: 2.0772 - sparse_categorical_accuracy: 0.2657 - val_loss: 1.9708 - val_sparse_categorical_accuracy: 0.2879
# Epoch 8/25
# 98/98 [==============================] - 1s 10ms/step - loss: 2.0628 - sparse_categorical_accuracy: 0.2778 - val_loss: 1.9425 - val_sparse_categorical_accuracy: 0.2945
# Epoch 9/25
# 98/98 [==============================] - 1s 9ms/step - loss: 1.9579 - sparse_categorical_accuracy: 0.2988 - val_loss: 1.9614 - val_sparse_categorical_accuracy: 0.2923
# Epoch 10/25
# 98/98 [==============================] - 1s 9ms/step - loss: 1.9413 - sparse_categorical_accuracy: 0.3083 - val_loss: 1.9582 - val_sparse_categorical_accuracy: 0.3057
# Epoch 11/25
# 98/98 [==============================] - 1s 10ms/step - loss: 1.9303 - sparse_categorical_accuracy: 0.3137 - val_loss: 2.0034 - val_sparse_categorical_accuracy: 0.2949
# Epoch 12/25
# 98/98 [==============================] - 1s 8ms/step - loss: 2.1430 - sparse_categorical_accuracy: 0.2783 - val_loss: 1.9523 - val_sparse_categorical_accuracy: 0.2987
# Epoch 13/25
# 98/98 [==============================] - 1s 9ms/step - loss: 1.9514 - sparse_categorical_accuracy: 0.3141 - val_loss: 1.9634 - val_sparse_categorical_accuracy: 0.3224
# Epoch 14/25
# 98/98 [==============================] - 1s 9ms/step - loss: 1.9874 - sparse_categorical_accuracy: 0.2989 - val_loss: 2.0006 - val_sparse_categorical_accuracy: 0.3087
# Epoch 15/25
# 98/98 [==============================] - 1s 9ms/step - loss: 1.9608 - sparse_categorical_accuracy: 0.3083 - val_loss: 1.9524 - val_sparse_categorical_accuracy: 0.3126
# Epoch 16/25
# 98/98 [==============================] - 1s 10ms/step - loss: 1.9508 - sparse_categorical_accuracy: 0.3159 - val_loss: 1.9417 - val_sparse_categorical_accuracy: 0.3145
# Epoch 17/25
# 98/98 [==============================] - 1s 10ms/step - loss: 1.9113 - sparse_categorical_accuracy: 0.3274 - val_loss: 1.9279 - val_sparse_categorical_accuracy: 0.3204
# Epoch 18/25
# 98/98 [==============================] - 1s 9ms/step - loss: 1.9250 - sparse_categorical_accuracy: 0.3216 - val_loss: 1.9800 - val_sparse_categorical_accuracy: 0.3130
# Epoch 19/25
# 98/98 [==============================] - 1s 9ms/step - loss: 1.8973 - sparse_categorical_accuracy: 0.3348 - val_loss: 1.8872 - val_sparse_categorical_accuracy: 0.3373
# Epoch 20/25
# 98/98 [==============================] - 1s 9ms/step - loss: 1.9174 - sparse_categorical_accuracy: 0.3286 - val_loss: 1.9703 - val_sparse_categorical_accuracy: 0.2985
# Epoch 21/25
# 98/98 [==============================] - 1s 8ms/step - loss: 1.9754 - sparse_categorical_accuracy: 0.3175 - val_loss: 1.9254 - val_sparse_categorical_accuracy: 0.3411
# Epoch 22/25
# 98/98 [==============================] - 1s 9ms/step - loss: 2.0552 - sparse_categorical_accuracy: 0.3057 - val_loss: 2.1086 - val_sparse_categorical_accuracy: 0.2936
# Epoch 23/25
# 98/98 [==============================] - 1s 9ms/step - loss: 2.0706 - sparse_categorical_accuracy: 0.3050 - val_loss: 2.0091 - val_sparse_categorical_accuracy: 0.3070
# Epoch 24/25
# 98/98 [==============================] - 1s 9ms/step - loss: 2.2045 - sparse_categorical_accuracy: 0.3034 - val_loss: 2.4433 - val_sparse_categorical_accuracy: 0.2640
# Epoch 25/25
# 98/98 [==============================] - 1s 8ms/step - loss: 2.0321 - sparse_categorical_accuracy: 0.3166 - val_loss: 1.9818 - val_sparse_categorical_accuracy: 0.3175
# Time taken for training:  28.269102096557617  seconds

# %%
start_time = time.time()
history_l2 = model_l2.fit(x_train,
                    y_train,
                    epochs=25,
                    batch_size=512,
                    validation_data=(x_test, y_test))
end_time = time.time()
total_time = end_time - start_time

print("Time taken for training (Model with dropout): ", total_time, " seconds")
# Out:
# Epoch 1/25
# 98/98 [==============================] - 3s 27ms/step - loss: 5.7809 - sparse_categorical_accuracy: 0.1463 - val_loss: 4.5700 - val_sparse_categorical_accuracy: 0.1590
# Epoch 2/25
# 98/98 [==============================] - 2s 16ms/step - loss: 3.7069 - sparse_categorical_accuracy: 0.1746 - val_loss: 3.2003 - val_sparse_categorical_accuracy: 0.2025
# Epoch 3/25
# 98/98 [==============================] - 2s 16ms/step - loss: 3.3965 - sparse_categorical_accuracy: 0.1965 - val_loss: 4.0137 - val_sparse_categorical_accuracy: 0.1451
# Epoch 4/25
# 98/98 [==============================] - 1s 14ms/step - loss: 2.8015 - sparse_categorical_accuracy: 0.2058 - val_loss: 2.6638 - val_sparse_categorical_accuracy: 0.2137
# Epoch 5/25
# 98/98 [==============================] - 2s 15ms/step - loss: 2.3869 - sparse_categorical_accuracy: 0.2335 - val_loss: 2.3336 - val_sparse_categorical_accuracy: 0.2237
# Epoch 6/25
# 98/98 [==============================] - 2s 16ms/step - loss: 2.3006 - sparse_categorical_accuracy: 0.2420 - val_loss: 2.2555 - val_sparse_categorical_accuracy: 0.2600
# Epoch 7/25
# 98/98 [==============================] - 2s 16ms/step - loss: 2.3165 - sparse_categorical_accuracy: 0.2506 - val_loss: 2.3154 - val_sparse_categorical_accuracy: 0.1931
# Epoch 8/25
# 98/98 [==============================] - 2s 16ms/step - loss: 2.3965 - sparse_categorical_accuracy: 0.2396 - val_loss: 2.1719 - val_sparse_categorical_accuracy: 0.2773
# Epoch 9/25
# 98/98 [==============================] - 1s 15ms/step - loss: 2.1469 - sparse_categorical_accuracy: 0.2882 - val_loss: 2.1238 - val_sparse_categorical_accuracy: 0.2986
# Epoch 10/25
# 98/98 [==============================] - 2s 16ms/step - loss: 2.1161 - sparse_categorical_accuracy: 0.2922 - val_loss: 2.1215 - val_sparse_categorical_accuracy: 0.2878
# Epoch 11/25
# 98/98 [==============================] - 1s 14ms/step - loss: 2.0803 - sparse_categorical_accuracy: 0.3091 - val_loss: 2.0632 - val_sparse_categorical_accuracy: 0.3194
# Epoch 12/25
# 98/98 [==============================] - 2s 17ms/step - loss: 2.0588 - sparse_categorical_accuracy: 0.3175 - val_loss: 2.0325 - val_sparse_categorical_accuracy: 0.3267
# Epoch 13/25
# 98/98 [==============================] - 2s 16ms/step - loss: 2.0454 - sparse_categorical_accuracy: 0.3189 - val_loss: 2.0108 - val_sparse_categorical_accuracy: 0.3277
# Epoch 14/25
# 98/98 [==============================] - 1s 14ms/step - loss: 2.0265 - sparse_categorical_accuracy: 0.3300 - val_loss: 2.0489 - val_sparse_categorical_accuracy: 0.3117
# Epoch 15/25
# 98/98 [==============================] - 1s 15ms/step - loss: 2.0341 - sparse_categorical_accuracy: 0.3245 - val_loss: 2.0048 - val_sparse_categorical_accuracy: 0.3355
# Epoch 16/25
# 98/98 [==============================] - 1s 14ms/step - loss: 2.0057 - sparse_categorical_accuracy: 0.3313 - val_loss: 1.9843 - val_sparse_categorical_accuracy: 0.3416
# Epoch 17/25
# 98/98 [==============================] - 2s 17ms/step - loss: 1.9996 - sparse_categorical_accuracy: 0.3337 - val_loss: 2.0203 - val_sparse_categorical_accuracy: 0.3193
# Epoch 18/25
# 98/98 [==============================] - 1s 15ms/step - loss: 1.9974 - sparse_categorical_accuracy: 0.3390 - val_loss: 1.9931 - val_sparse_categorical_accuracy: 0.3334
# Epoch 19/25
# 98/98 [==============================] - 1s 14ms/step - loss: 1.9931 - sparse_categorical_accuracy: 0.3439 - val_loss: 1.9957 - val_sparse_categorical_accuracy: 0.3348
# Epoch 20/25
# 98/98 [==============================] - 1s 14ms/step - loss: 2.0001 - sparse_categorical_accuracy: 0.3431 - val_loss: 1.9906 - val_sparse_categorical_accuracy: 0.3464
# Epoch 21/25
# 98/98 [==============================] - 1s 15ms/step - loss: 2.0102 - sparse_categorical_accuracy: 0.3442 - val_loss: 2.0001 - val_sparse_categorical_accuracy: 0.3560
# Epoch 22/25
# 98/98 [==============================] - 2s 19ms/step - loss: 2.0186 - sparse_categorical_accuracy: 0.3442 - val_loss: 2.0296 - val_sparse_categorical_accuracy: 0.3443
# Epoch 23/25
# 98/98 [==============================] - 1s 14ms/step - loss: 2.0212 - sparse_categorical_accuracy: 0.3468 - val_loss: 2.0105 - val_sparse_categorical_accuracy: 0.3605
# Epoch 24/25
# 98/98 [==============================] - 2s 15ms/step - loss: 2.0673 - sparse_categorical_accuracy: 0.3318 - val_loss: 2.0521 - val_sparse_categorical_accuracy: 0.3436
# Epoch 25/25
# 98/98 [==============================] - 1s 14ms/step - loss: 2.0768 - sparse_categorical_accuracy: 0.3400 - val_loss: 2.0619 - val_sparse_categorical_accuracy: 0.3524
# Time taken for training (Model with dropout):  45.62875986099243  seconds

# %% [markdown]
# #### Plot Accuracy

# %%
# Plot the accuracy from the training history
plt.plot(history.history['sparse_categorical_accuracy'])
plt.plot(history.history['val_sparse_categorical_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot the accuracy from the training history
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot the accuracy from the training history
plt.plot(history_l2.history['sparse_categorical_accuracy'])
plt.plot(history_l2.history['val_sparse_categorical_accuracy'])
plt.title('Model Accuracy (Dropout)')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot the accuracy from the training history
plt.plot(history_l2.history['loss'])
plt.plot(history_l2.history['val_loss'])
plt.title('Loss (Dropout)')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# #### Save model

# %%
if not os.path.exists(model_directory):
    os.makedirs(model_directory)
model_path = os.path.join(model_directory,"model_nn.h5")
model.save(model_path)

model_path_dropout = os.path.join(model_directory,"model_nn_l2.h5")
model_with_dropout.save(model_path_dropout)
# Out:
# /Users/binilkuriachan/anaconda3/envs/ail-411-env/lib/python3.9/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 7
#       4 model.save(model_path)
#       6 model_path_dropout = os.path.join(model_directory,"model_nn_l2.h5")
# ----> 7 model_with_dropout.save(model_path_dropout)
#
# NameError: name 'model_with_dropout' is not defined

# %% [markdown]
# #### Load Model

# %%
# Load the saved model from a file
loaded_model = tf.keras.models.load_model(model_path)
loaded_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 3072)              0
#
#  dense (Dense)               (None, 128)               393344
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 394634 (1.51 MB)
# Trainable params: 394634 (1.51 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Load the saved model from a file
model_path = os.path.join(model_directory,"model_nn_dropout.h5")
loaded_model_dropout = tf.keras.models.load_model(model_path_dropout)
loaded_model_dropout.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 3072)              0
#
#  dense_3 (Dense)             (None, 128)               393344
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_4 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 394634 (1.51 MB)
# Trainable params: 394634 (1.51 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #### Predict

# %%
# Get the true labels and predicted labels for the test dataset
true_labels = np.concatenate([y for x, y in zip(x_test,y_test)], axis=0)
predicted_labels = np.argmax(model.predict(x_test), axis=-1)
# Out:
# 313/313 [==============================] - 0s 1ms/step

# %%
# Get the true labels and predicted labels for the test dataset
true_labels = np.concatenate([y for x, y in zip(x_test,y_test)], axis=0)
predicted_labels_dropout = np.argmax(loaded_model_dropout.predict(x_test), axis=-1)
# Out:
# 313/313 [==============================] - 0s 1ms/step

# %% [markdown]
# #### Confusion Matrix

# %%
# Generate the confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)

# Plot the confusion matrix
plt.imshow(cm, cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.xticks(np.arange(10))
plt.yticks(np.arange(10))
plt.show()

# %%
# Generate the confusion matrix
cm = confusion_matrix(true_labels, predicted_labels_dropout)

# Plot the confusion matrix
plt.imshow(cm, cmap=plt.cm.Blues)
plt.title('Confusion Matrix (Dropout)')
plt.colorbar()
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.xticks(np.arange(10))
plt.yticks(np.arange(10))
plt.show()

# %% [markdown]
# #### Classification Report

# %%
# Generate the classification report
report = classification_report(true_labels, predicted_labels, target_names=cifar_10_labels.values(),)

# Print the classification report
print(report)
# Out:
#               precision    recall  f1-score   support
#
#     airplane       0.38      0.53      0.44      1000
#   automobile       0.51      0.39      0.45      1000
#         bird       0.29      0.01      0.03      1000
#          cat       0.28      0.18      0.22      1000
#         deer       0.29      0.43      0.34      1000
#          dog       0.27      0.39      0.32      1000
#         frog       0.33      0.62      0.43      1000
#        horse       0.61      0.23      0.34      1000
#         ship       0.42      0.56      0.48      1000
#        truck       0.53      0.33      0.41      1000
#
#     accuracy                           0.37     10000
#    macro avg       0.39      0.37      0.35     10000
# weighted avg       0.39      0.37      0.35     10000

# %%
# Generate the classification report
report = classification_report(true_labels, predicted_labels_dropout, target_names=cifar_10_labels.values(),)

# Print the classification report
print(report)
# Out:
#               precision    recall  f1-score   support
#
#     airplane       0.40      0.49      0.44      1000
#   automobile       0.46      0.43      0.44      1000
#         bird       0.29      0.20      0.24      1000
#          cat       0.22      0.43      0.29      1000
#         deer       0.48      0.07      0.13      1000
#          dog       0.42      0.23      0.30      1000
#         frog       0.37      0.46      0.41      1000
#        horse       0.38      0.49      0.43      1000
#         ship       0.49      0.37      0.42      1000
#        truck       0.43      0.51      0.47      1000
#
#     accuracy                           0.37     10000
#    macro avg       0.39      0.37      0.36     10000
# weighted avg       0.39      0.37      0.36     10000

# %% [markdown]
# #### In multi-class classification problems, macro-average and micro-average are two commonly used methods to calculate precision, recall, and accuracy.
#
# Micro-average calculates the metrics globally by counting the total true positives, false negatives, and false positives across all classes. Micro-average is useful when you want to weight each instance or prediction equally, regardless of the class.
#
# Macro-average calculates the metrics for each class separately and then takes the average across all classes. Macro-average is useful when you want to weight each class equally, regardless of the number of instances or predictions in each class.
#
# Here's a brief explanation of the differences between micro-average and macro-average for precision, recall, and accuracy:
# Micro-average precision, recall, and accuracy are calculated by counting the total true positives, false negatives, and false positives across all classes and then calculating the precision, recall, and accuracy from those counts. Micro-average gives equal weight to each instance or prediction, regardless of the class.
#
# * Macro-average precision, recall, and accuracy are calculated by calculating the precision, recall, and accuracy for each class separately and then taking the average across all classes.
# * Macro-average gives equal weight to each class, regardless of the number of instances or predictions in each class.
