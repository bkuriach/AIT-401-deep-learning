# %%
import os
import time
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
import tensorflow_datasets as tfds
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras import (
    models,
    layers,
) 
from matplotlib import pyplot as plt
import numpy as np
import random
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt

# %%
cifar_10_labels = {
    0: 'airplane',
    1: 'automobile',
    2: 'bird',
    3: 'cat',
    4: 'deer',
    5: 'dog',
    6: 'frog',
    7: 'horse',
    8: 'ship',
    9: 'truck'
    }

model_directory = 'models'

# %%
class RandomIntegers():
    def __init__(self):
        pass
    
    def generate(self, n, length):
        # Generate n unique random integers between 0 and length
        random_integers = random.sample(range(length), n)
        
        return random_integers

# %% [markdown]
# #### CIFAR-10
# ###### CIFAR-10 dataset consists of 60000 32×32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.

# %%
# Load the CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train/255
x_test = x_test/255

# %% [markdown]
# ### Plot dataset

# %%
def display_images():
    random_integers = RandomIntegers().generate(9, len(x_train))
    plt.figure(figsize=(6, 8))
    counter = 0
    for i in random_integers:
        # define subplot
        plt.subplot(330 + 1 + counter)
        counter += 1
        # plot raw pixel data
        plt.imshow(x_train[i])
        plt.title(cifar_10_labels[y_train[i][0]])
    # show the figure
    plt.show()
display_images()

# %% [markdown]
# ### Kaiming Initialization
#
# Weight initialization is used to define the initial values for the parameters in neural network models prior to training the models on a dataset.
#
# Neural networks are trained using optimizers such as Gradient Descent, Adam etc that incrementally changes the network weights to minimize the loss funciton. The optimization algorithms requires a starting point in the space of possible weights to begin the optimization process. Weight initialization is a procedure to set the weights of a neural network to small random values that define the starting point for the optimization (learning or training) of the neural network model.
#
# Kaiming initialization, or He initialization, is a method for initializing neural network weights that considers the non-linearity of activation functions, such as ReLU

# %% [markdown]
# ### Build Model

# %%
model = tensorflow.keras.models.Sequential([
    
    tensorflow.keras.layers.Flatten(input_shape=(32, 32, 3)),
    tensorflow.keras.layers.Dense(128, 
                                  activation='relu', 
                                  kernel_initializer=tf.keras.initializers.HeNormal()
                                 ),
    # tensorflow.keras.layers.Dense(32, activation='relu'),
    tensorflow.keras.layers.Dense(10, 
                                  activation='softmax',
                                  kernel_initializer=tf.keras.initializers.HeNormal()
                                 )
])

# %% [markdown]
# ### Compiling the model

# %%
# model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.compile(
    optimizer=tf.keras.optimizers.Adam(0.001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.

# %% [markdown]
# #### Model Training

# %%
start_time = time.time()
history = model.fit(x_train,
                    y_train,
                    epochs=25,
                    batch_size=512,
                    validation_data=(x_test, y_test))
end_time = time.time()
total_time = end_time - start_time

print("Time taken for training: ", total_time, " seconds")
# Out:
# Epoch 1/25
# /Users/binilkuriachan/anaconda3/envs/ail-411-env/lib/python3.9/site-packages/keras/src/backend.py:5714: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 98/98 [==============================] - 1s 10ms/step - loss: 2.9677 - sparse_categorical_accuracy: 0.1892 - val_loss: 2.0862 - val_sparse_categorical_accuracy: 0.2279
# Epoch 2/25
# 98/98 [==============================] - 1s 7ms/step - loss: 2.0374 - sparse_categorical_accuracy: 0.2621 - val_loss: 2.0038 - val_sparse_categorical_accuracy: 0.2753
# Epoch 3/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.9749 - sparse_categorical_accuracy: 0.2927 - val_loss: 1.9632 - val_sparse_categorical_accuracy: 0.2918
# Epoch 4/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.9282 - sparse_categorical_accuracy: 0.3129 - val_loss: 1.9198 - val_sparse_categorical_accuracy: 0.3130
# Epoch 5/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.9001 - sparse_categorical_accuracy: 0.3242 - val_loss: 1.8993 - val_sparse_categorical_accuracy: 0.3269
# Epoch 6/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.8766 - sparse_categorical_accuracy: 0.3359 - val_loss: 1.8513 - val_sparse_categorical_accuracy: 0.3493
# Epoch 7/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.8531 - sparse_categorical_accuracy: 0.3436 - val_loss: 1.8481 - val_sparse_categorical_accuracy: 0.3411
# Epoch 8/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.8343 - sparse_categorical_accuracy: 0.3537 - val_loss: 1.8298 - val_sparse_categorical_accuracy: 0.3588
# Epoch 9/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.8183 - sparse_categorical_accuracy: 0.3606 - val_loss: 1.8428 - val_sparse_categorical_accuracy: 0.3500
# Epoch 10/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.8147 - sparse_categorical_accuracy: 0.3618 - val_loss: 1.8312 - val_sparse_categorical_accuracy: 0.3557
# Epoch 11/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.8135 - sparse_categorical_accuracy: 0.3610 - val_loss: 1.8048 - val_sparse_categorical_accuracy: 0.3609
# Epoch 12/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.8005 - sparse_categorical_accuracy: 0.3682 - val_loss: 1.8147 - val_sparse_categorical_accuracy: 0.3694
# Epoch 13/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7865 - sparse_categorical_accuracy: 0.3743 - val_loss: 1.8014 - val_sparse_categorical_accuracy: 0.3683
# Epoch 14/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7775 - sparse_categorical_accuracy: 0.3793 - val_loss: 1.7913 - val_sparse_categorical_accuracy: 0.3724
# Epoch 15/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7733 - sparse_categorical_accuracy: 0.3807 - val_loss: 1.7935 - val_sparse_categorical_accuracy: 0.3681
# Epoch 16/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7719 - sparse_categorical_accuracy: 0.3802 - val_loss: 1.7820 - val_sparse_categorical_accuracy: 0.3684
# Epoch 17/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7695 - sparse_categorical_accuracy: 0.3820 - val_loss: 1.7908 - val_sparse_categorical_accuracy: 0.3675
# Epoch 18/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7620 - sparse_categorical_accuracy: 0.3830 - val_loss: 1.7749 - val_sparse_categorical_accuracy: 0.3821
# Epoch 19/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7669 - sparse_categorical_accuracy: 0.3822 - val_loss: 1.7659 - val_sparse_categorical_accuracy: 0.3796
# Epoch 20/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7685 - sparse_categorical_accuracy: 0.3813 - val_loss: 1.7749 - val_sparse_categorical_accuracy: 0.3753
# Epoch 21/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7577 - sparse_categorical_accuracy: 0.3855 - val_loss: 1.7913 - val_sparse_categorical_accuracy: 0.3684
# Epoch 22/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7522 - sparse_categorical_accuracy: 0.3895 - val_loss: 1.7628 - val_sparse_categorical_accuracy: 0.3905
# Epoch 23/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7471 - sparse_categorical_accuracy: 0.3898 - val_loss: 1.7608 - val_sparse_categorical_accuracy: 0.3805
# Epoch 24/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7468 - sparse_categorical_accuracy: 0.3902 - val_loss: 1.7607 - val_sparse_categorical_accuracy: 0.3861
# Epoch 25/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7559 - sparse_categorical_accuracy: 0.3865 - val_loss: 1.7975 - val_sparse_categorical_accuracy: 0.3704
# Time taken for training:  18.711881160736084  seconds

# %% [markdown]
# #### Plot Accuracy

# %%
# Plot the accuracy from the training history
plt.plot(history.history['sparse_categorical_accuracy'])
plt.plot(history.history['val_sparse_categorical_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot the accuracy from the training history
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# #### Save model

# %%
if not os.path.exists(model_directory):
    os.makedirs(model_directory)
model_path = os.path.join(model_directory,"model_nn_kaiming.h5")
model.save(model_path)
# Out:
# /Users/binilkuriachan/anaconda3/envs/ail-411-env/lib/python3.9/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# #### Load Model

# %%
# Load the saved model from a file
loaded_model = tf.keras.models.load_model(model_path)
loaded_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 3072)              0
#
#  dense (Dense)               (None, 128)               393344
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 394634 (1.51 MB)
# Trainable params: 394634 (1.51 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #### Predict

# %%
# Get the true labels and predicted labels for the test dataset
true_labels = np.concatenate([y for x, y in zip(x_test,y_test)], axis=0)
predicted_labels = np.argmax(model.predict(x_test), axis=-1)
# Out:
# 313/313 [==============================] - 0s 1ms/step

# %% [markdown]
# #### Confusion Matrix

# %%
# Generate the confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)

# Plot the confusion matrix
plt.imshow(cm, cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.xticks(np.arange(10))
plt.yticks(np.arange(10))
plt.show()

# %% [markdown]
# #### Classification Report

# %%
# Generate the classification report
report = classification_report(true_labels, predicted_labels, target_names=cifar_10_labels.values(),)

# Print the classification report
print(report)
# Out:
#               precision    recall  f1-score   support
#
#     airplane       0.67      0.11      0.18      1000
#   automobile       0.45      0.51      0.48      1000
#         bird       0.27      0.18      0.22      1000
#          cat       0.26      0.22      0.24      1000
#         deer       0.43      0.12      0.18      1000
#          dog       0.32      0.36      0.34      1000
#         frog       0.35      0.65      0.46      1000
#        horse       0.35      0.55      0.43      1000
#         ship       0.43      0.56      0.48      1000
#        truck       0.44      0.45      0.44      1000
#
#     accuracy                           0.37     10000
#    macro avg       0.40      0.37      0.34     10000
# weighted avg       0.40      0.37      0.34     10000

# %% [markdown]
# #### In multi-class classification problems, macro-average and micro-average are two commonly used methods to calculate precision, recall, and accuracy.
#
# Micro-average calculates the metrics globally by counting the total true positives, false negatives, and false positives across all classes. Micro-average is useful when you want to weight each instance or prediction equally, regardless of the class.
#
# Macro-average calculates the metrics for each class separately and then takes the average across all classes. Macro-average is useful when you want to weight each class equally, regardless of the number of instances or predictions in each class.
#
# Here's a brief explanation of the differences between micro-average and macro-average for precision, recall, and accuracy:
# Micro-average precision, recall, and accuracy are calculated by counting the total true positives, false negatives, and false positives across all classes and then calculating the precision, recall, and accuracy from those counts. Micro-average gives equal weight to each instance or prediction, regardless of the class.
#
# * Macro-average precision, recall, and accuracy are calculated by calculating the precision, recall, and accuracy for each class separately and then taking the average across all classes.
# * Macro-average gives equal weight to each class, regardless of the number of instances or predictions in each class.
