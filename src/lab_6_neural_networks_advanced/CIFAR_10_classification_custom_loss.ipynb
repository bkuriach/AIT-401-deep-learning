# %%
import os
import time
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
import tensorflow_datasets as tfds
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras import (
    models,
    layers,
) 
from matplotlib import pyplot as plt
import numpy as np
import random
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt

# %%
cifar_10_labels = {
    0: 'airplane',
    1: 'automobile',
    2: 'bird',
    3: 'cat',
    4: 'deer',
    5: 'dog',
    6: 'frog',
    7: 'horse',
    8: 'ship',
    9: 'truck'
    }

model_directory = 'models'

# %%
class RandomIntegers():
    def __init__(self):
        pass
    
    def generate(self, n, length):
        # Generate n unique random integers between 0 and length
        random_integers = random.sample(range(length), n)
        
        return random_integers

# %% [markdown]
# #### CIFAR-10
# ###### CIFAR-10 dataset consists of 60000 32×32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.

# %%
# Load the CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train/255
x_test = x_test/255

# %% [markdown]
# ### Plot dataset

# %%
def display_images():
    random_integers = RandomIntegers().generate(9, len(x_train))
    plt.figure(figsize=(6, 8))
    counter = 0
    for i in random_integers:
        # define subplot
        plt.subplot(330 + 1 + counter)
        counter += 1
        # plot raw pixel data
        plt.imshow(x_train[i])
        plt.title(cifar_10_labels[y_train[i][0]])
    # show the figure
    plt.show()
display_images()

# %% [markdown]
# ### Regularization
#
# Add details here

# %% [markdown]
# ### Build Model

# %%
model = tensorflow.keras.models.Sequential([
    
    tensorflow.keras.layers.Flatten(input_shape=(32, 32, 3)),
    tensorflow.keras.layers.Dense(128, 
                                  activation='relu', 
                                 ),
    tensorflow.keras.layers.Dense(32, activation='relu'),
    tensorflow.keras.layers.Dense(10, 
                                  activation='softmax',
                                 )
])

# %%
def l2_loss(y_true, y_pred):
    # get the original loss value 
    original_loss = tensorflow.keras.losses.sparse_categorical_crossentropy(y_true, y_pred)
    # get the model weights
    weights = model_l2.trainable_weights
    # compute the l2 norm of the weights
    l2_norm = tensorflow.reduce_sum([tensorflow.reduce_sum(tensorflow.square(w)) for w in weights])
    # add the l2 penalty factor
    l2_penalty = 0.01
    
    return original_loss + l2_penalty * l2_norm

# %%
# y_true = tf.convert_to_tensor(np.array([1,1,1,1]),dtype=tf.float32)
# y_pred = tf.convert_to_tensor(np.array([1,1,0,1]),dtype=tf.float32)
# l2_loss(y_true, y_pred)

# %%
tensorflow.keras.losses.categorical_crossentropy(y_true, y_pred)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=19.413933>

# %%
model_l2 = tensorflow.keras.models.Sequential([
    
    tensorflow.keras.layers.Flatten(input_shape=(32, 32, 3)),
    tensorflow.keras.layers.Dense(
                                  128, 
                                  activation='relu', 
                                 ),
    tensorflow.keras.layers.Dense(
                                  32, 
                                  activation='relu',
    ),
    tensorflow.keras.layers.Dense(10, 
                                  activation='softmax',
                                 )
])

# %% [markdown]
# ### Compiling the model

# %%
# model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.compile(
    optimizer=tf.keras.optimizers.Adam(0.001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.

# %%
model_l2.compile(
    optimizer=tf.keras.optimizers.Adam(0.001),
    loss=l2_loss,
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.

# %% [markdown]
# #### Model Training

# %%
start_time = time.time()
history = model.fit(x_train,
                    y_train,
                    epochs=25,
                    batch_size=512,
                    validation_data=(x_test, y_test))
end_time = time.time()
total_time = end_time - start_time

print("Time taken for training: ", total_time, " seconds")
# Out:
# Epoch 1/25
# /Users/binilkuriachan/anaconda3/envs/ail-411-env/lib/python3.9/site-packages/keras/src/backend.py:5714: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 98/98 [==============================] - 3s 22ms/step - loss: 4.8181 - sparse_categorical_accuracy: 0.1534 - val_loss: 2.1735 - val_sparse_categorical_accuracy: 0.2110
# Epoch 2/25
# 98/98 [==============================] - 1s 10ms/step - loss: 2.1713 - sparse_categorical_accuracy: 0.2131 - val_loss: 2.1712 - val_sparse_categorical_accuracy: 0.2205
# Epoch 3/25
# 98/98 [==============================] - 1s 9ms/step - loss: 2.2187 - sparse_categorical_accuracy: 0.2102 - val_loss: 2.2088 - val_sparse_categorical_accuracy: 0.2214
# Epoch 4/25
# 98/98 [==============================] - 1s 10ms/step - loss: 2.1702 - sparse_categorical_accuracy: 0.2242 - val_loss: 2.1323 - val_sparse_categorical_accuracy: 0.2349
# Epoch 5/25
# 98/98 [==============================] - 1s 9ms/step - loss: 2.1064 - sparse_categorical_accuracy: 0.2429 - val_loss: 2.1446 - val_sparse_categorical_accuracy: 0.2485
# Epoch 6/25
# 98/98 [==============================] - 1s 8ms/step - loss: 2.0986 - sparse_categorical_accuracy: 0.2561 - val_loss: 2.0963 - val_sparse_categorical_accuracy: 0.2661
# Epoch 7/25
# 98/98 [==============================] - 1s 9ms/step - loss: 2.1121 - sparse_categorical_accuracy: 0.2571 - val_loss: 2.0424 - val_sparse_categorical_accuracy: 0.2673
# Epoch 8/25
# 98/98 [==============================] - 1s 8ms/step - loss: 2.0141 - sparse_categorical_accuracy: 0.2738 - val_loss: 2.0153 - val_sparse_categorical_accuracy: 0.2696
# Epoch 9/25
# 98/98 [==============================] - 1s 9ms/step - loss: 1.9922 - sparse_categorical_accuracy: 0.2771 - val_loss: 1.9585 - val_sparse_categorical_accuracy: 0.2886
# Epoch 10/25
# 98/98 [==============================] - 1s 8ms/step - loss: 1.9694 - sparse_categorical_accuracy: 0.2907 - val_loss: 1.9642 - val_sparse_categorical_accuracy: 0.2979
# Epoch 11/25
# 98/98 [==============================] - 1s 9ms/step - loss: 1.9607 - sparse_categorical_accuracy: 0.2972 - val_loss: 1.9793 - val_sparse_categorical_accuracy: 0.2858
# Epoch 12/25
# 98/98 [==============================] - 1s 11ms/step - loss: 1.9350 - sparse_categorical_accuracy: 0.3047 - val_loss: 1.9307 - val_sparse_categorical_accuracy: 0.3073
# Epoch 13/25
# 98/98 [==============================] - 1s 9ms/step - loss: 1.9523 - sparse_categorical_accuracy: 0.3069 - val_loss: 1.9229 - val_sparse_categorical_accuracy: 0.3212
# Epoch 14/25
# 98/98 [==============================] - 1s 9ms/step - loss: 1.9380 - sparse_categorical_accuracy: 0.3124 - val_loss: 1.9786 - val_sparse_categorical_accuracy: 0.2895
# Epoch 15/25
# 98/98 [==============================] - 1s 8ms/step - loss: 1.9332 - sparse_categorical_accuracy: 0.3136 - val_loss: 1.9946 - val_sparse_categorical_accuracy: 0.2996
# Epoch 16/25
# 98/98 [==============================] - 1s 9ms/step - loss: 1.9447 - sparse_categorical_accuracy: 0.3176 - val_loss: 1.9314 - val_sparse_categorical_accuracy: 0.3131
# Epoch 17/25
# 98/98 [==============================] - 1s 9ms/step - loss: 1.9331 - sparse_categorical_accuracy: 0.3233 - val_loss: 2.0823 - val_sparse_categorical_accuracy: 0.2946
# Epoch 18/25
# 98/98 [==============================] - 1s 9ms/step - loss: 1.9680 - sparse_categorical_accuracy: 0.3185 - val_loss: 1.9252 - val_sparse_categorical_accuracy: 0.3309
# Epoch 19/25
# 98/98 [==============================] - 1s 9ms/step - loss: 1.9461 - sparse_categorical_accuracy: 0.3178 - val_loss: 1.9236 - val_sparse_categorical_accuracy: 0.3268
# Epoch 20/25
# 98/98 [==============================] - 1s 10ms/step - loss: 1.9645 - sparse_categorical_accuracy: 0.3187 - val_loss: 2.0626 - val_sparse_categorical_accuracy: 0.2887
# Epoch 21/25
# 98/98 [==============================] - 1s 9ms/step - loss: 1.9963 - sparse_categorical_accuracy: 0.3106 - val_loss: 2.1776 - val_sparse_categorical_accuracy: 0.2868
# Epoch 22/25
# 98/98 [==============================] - 1s 9ms/step - loss: 2.0005 - sparse_categorical_accuracy: 0.3070 - val_loss: 1.9246 - val_sparse_categorical_accuracy: 0.3145
# Epoch 23/25
# 98/98 [==============================] - 1s 9ms/step - loss: 2.0210 - sparse_categorical_accuracy: 0.3085 - val_loss: 2.1839 - val_sparse_categorical_accuracy: 0.2835
# Epoch 24/25
# 98/98 [==============================] - 1s 9ms/step - loss: 2.0106 - sparse_categorical_accuracy: 0.3105 - val_loss: 1.9893 - val_sparse_categorical_accuracy: 0.3007
# Epoch 25/25
# 98/98 [==============================] - 1s 8ms/step - loss: 2.0060 - sparse_categorical_accuracy: 0.3128 - val_loss: 2.1126 - val_sparse_categorical_accuracy: 0.2952
# Time taken for training:  30.17529797554016  seconds

# %%
start_time = time.time()
history_l2 = model_l2.fit(x_train,
                    y_train,
                    epochs=25,
                    batch_size=512,
                    validation_data=(x_test, y_test))
end_time = time.time()
total_time = end_time - start_time

print("Time taken for training (Model with ): ", total_time, " seconds")
# Out:
# Epoch 1/25
# 98/98 [==============================] - 3s 25ms/step - loss: 5.4446 - sparse_categorical_accuracy: 0.1624 - val_loss: 3.4648 - val_sparse_categorical_accuracy: 0.2555
# Epoch 2/25
# 98/98 [==============================] - 1s 12ms/step - loss: 3.1487 - sparse_categorical_accuracy: 0.2215 - val_loss: 2.8406 - val_sparse_categorical_accuracy: 0.2668
# Epoch 3/25
# 98/98 [==============================] - 1s 11ms/step - loss: 2.9896 - sparse_categorical_accuracy: 0.2178 - val_loss: 2.9123 - val_sparse_categorical_accuracy: 0.2175
# Epoch 4/25
# 98/98 [==============================] - 1s 11ms/step - loss: 3.1158 - sparse_categorical_accuracy: 0.1903 - val_loss: 3.3261 - val_sparse_categorical_accuracy: 0.1432
# Epoch 5/25
# 98/98 [==============================] - 1s 12ms/step - loss: 2.8691 - sparse_categorical_accuracy: 0.1898 - val_loss: 2.4971 - val_sparse_categorical_accuracy: 0.2544
# Epoch 6/25
# 98/98 [==============================] - 1s 12ms/step - loss: 2.8798 - sparse_categorical_accuracy: 0.1955 - val_loss: 2.5162 - val_sparse_categorical_accuracy: 0.2187
# Epoch 7/25
# 98/98 [==============================] - 1s 13ms/step - loss: 2.5065 - sparse_categorical_accuracy: 0.2248 - val_loss: 2.6598 - val_sparse_categorical_accuracy: 0.1886
# Epoch 8/25
# 98/98 [==============================] - 1s 12ms/step - loss: 2.5516 - sparse_categorical_accuracy: 0.2272 - val_loss: 2.5841 - val_sparse_categorical_accuracy: 0.1763
# Epoch 9/25
# 98/98 [==============================] - 1s 11ms/step - loss: 2.5859 - sparse_categorical_accuracy: 0.2023 - val_loss: 2.4688 - val_sparse_categorical_accuracy: 0.2249
# Epoch 10/25
# 98/98 [==============================] - 1s 12ms/step - loss: 2.4421 - sparse_categorical_accuracy: 0.2154 - val_loss: 2.4252 - val_sparse_categorical_accuracy: 0.2043
# Epoch 11/25
# 98/98 [==============================] - 1s 12ms/step - loss: 2.4191 - sparse_categorical_accuracy: 0.2151 - val_loss: 2.5103 - val_sparse_categorical_accuracy: 0.1828
# Epoch 12/25
# 98/98 [==============================] - 1s 12ms/step - loss: 2.4078 - sparse_categorical_accuracy: 0.2244 - val_loss: 2.3243 - val_sparse_categorical_accuracy: 0.2629
# Epoch 13/25
# 98/98 [==============================] - 1s 12ms/step - loss: 2.3153 - sparse_categorical_accuracy: 0.2562 - val_loss: 2.3014 - val_sparse_categorical_accuracy: 0.2605
# Epoch 14/25
# 98/98 [==============================] - 1s 11ms/step - loss: 2.2971 - sparse_categorical_accuracy: 0.2562 - val_loss: 2.2651 - val_sparse_categorical_accuracy: 0.2579
# Epoch 15/25
# 98/98 [==============================] - 1s 12ms/step - loss: 2.2784 - sparse_categorical_accuracy: 0.2614 - val_loss: 2.2461 - val_sparse_categorical_accuracy: 0.2750
# Epoch 16/25
# 98/98 [==============================] - 1s 11ms/step - loss: 2.2710 - sparse_categorical_accuracy: 0.2652 - val_loss: 2.2813 - val_sparse_categorical_accuracy: 0.2514
# Epoch 17/25
# 98/98 [==============================] - 1s 13ms/step - loss: 2.2813 - sparse_categorical_accuracy: 0.2644 - val_loss: 2.2191 - val_sparse_categorical_accuracy: 0.2789
# Epoch 18/25
# 98/98 [==============================] - 1s 12ms/step - loss: 2.2078 - sparse_categorical_accuracy: 0.2861 - val_loss: 2.1917 - val_sparse_categorical_accuracy: 0.2732
# Epoch 19/25
# 98/98 [==============================] - 1s 13ms/step - loss: 2.1866 - sparse_categorical_accuracy: 0.3007 - val_loss: 2.1617 - val_sparse_categorical_accuracy: 0.3138
# Epoch 20/25
# 98/98 [==============================] - 1s 13ms/step - loss: 2.1684 - sparse_categorical_accuracy: 0.3050 - val_loss: 2.1667 - val_sparse_categorical_accuracy: 0.2999
# Epoch 21/25
# 98/98 [==============================] - 1s 11ms/step - loss: 2.1621 - sparse_categorical_accuracy: 0.3044 - val_loss: 2.1770 - val_sparse_categorical_accuracy: 0.2833
# Epoch 22/25
# 98/98 [==============================] - 1s 12ms/step - loss: 2.1430 - sparse_categorical_accuracy: 0.3171 - val_loss: 2.1349 - val_sparse_categorical_accuracy: 0.3237
# Epoch 23/25
# 98/98 [==============================] - 1s 13ms/step - loss: 2.1326 - sparse_categorical_accuracy: 0.3186 - val_loss: 2.1473 - val_sparse_categorical_accuracy: 0.2993
# Epoch 24/25
# 98/98 [==============================] - 1s 12ms/step - loss: 2.1471 - sparse_categorical_accuracy: 0.3055 - val_loss: 2.1094 - val_sparse_categorical_accuracy: 0.3242
# Epoch 25/25
# 98/98 [==============================] - 1s 12ms/step - loss: 2.1306 - sparse_categorical_accuracy: 0.3113 - val_loss: 2.1335 - val_sparse_categorical_accuracy: 0.2955
# Time taken for training (Model with ):  33.49190306663513  seconds

# %% [markdown]
# #### Plot Accuracy

# %%
# Plot the accuracy from the training history
plt.plot(history.history['sparse_categorical_accuracy'])
plt.plot(history.history['val_sparse_categorical_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot the accuracy from the training history
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot the accuracy from the training history
plt.plot(history_l2.history['sparse_categorical_accuracy'])
plt.plot(history_l2.history['val_sparse_categorical_accuracy'])
plt.title('Model Accuracy (Dropout)')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot the accuracy from the training history
plt.plot(history_l2.history['loss'])
plt.plot(history_l2.history['val_loss'])
plt.title('Loss (Dropout)')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# #### Save model

# %%
if not os.path.exists(model_directory):
    os.makedirs(model_directory)
model_path = os.path.join(model_directory,"model_nn.h5")
model.save(model_path)

model_path_l2 = os.path.join(model_directory,"model_nn_l2.h5")
model_l2.save(model_path_dropout)

# %% [markdown]
# #### Load Model

# %%
# Load the saved model from a file
loaded_model = tf.keras.models.load_model(model_path)
loaded_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 3072)              0
#
#  dense (Dense)               (None, 128)               393344
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 394634 (1.51 MB)
# Trainable params: 394634 (1.51 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Load the saved model from a file
model_path = os.path.join(model_directory,"model_nn_dropout.h5")
loaded_model_dropout = tf.keras.models.load_model(model_path_dropout)
loaded_model_dropout.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 3072)              0
#
#  dense_3 (Dense)             (None, 128)               393344
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_4 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 394634 (1.51 MB)
# Trainable params: 394634 (1.51 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #### Predict

# %%
# Get the true labels and predicted labels for the test dataset
true_labels = np.concatenate([y for x, y in zip(x_test,y_test)], axis=0)
predicted_labels = np.argmax(model.predict(x_test), axis=-1)
# Out:
# 313/313 [==============================] - 0s 1ms/step

# %%
# Get the true labels and predicted labels for the test dataset
true_labels = np.concatenate([y for x, y in zip(x_test,y_test)], axis=0)
predicted_labels_dropout = np.argmax(loaded_model_dropout.predict(x_test), axis=-1)
# Out:
# 313/313 [==============================] - 0s 1ms/step

# %% [markdown]
# #### Confusion Matrix

# %%
# Generate the confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)

# Plot the confusion matrix
plt.imshow(cm, cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.xticks(np.arange(10))
plt.yticks(np.arange(10))
plt.show()

# %%
# Generate the confusion matrix
cm = confusion_matrix(true_labels, predicted_labels_dropout)

# Plot the confusion matrix
plt.imshow(cm, cmap=plt.cm.Blues)
plt.title('Confusion Matrix (Dropout)')
plt.colorbar()
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.xticks(np.arange(10))
plt.yticks(np.arange(10))
plt.show()

# %% [markdown]
# #### Classification Report

# %%
# Generate the classification report
report = classification_report(true_labels, predicted_labels, target_names=cifar_10_labels.values(),)

# Print the classification report
print(report)
# Out:
#               precision    recall  f1-score   support
#
#     airplane       0.38      0.53      0.44      1000
#   automobile       0.51      0.39      0.45      1000
#         bird       0.29      0.01      0.03      1000
#          cat       0.28      0.18      0.22      1000
#         deer       0.29      0.43      0.34      1000
#          dog       0.27      0.39      0.32      1000
#         frog       0.33      0.62      0.43      1000
#        horse       0.61      0.23      0.34      1000
#         ship       0.42      0.56      0.48      1000
#        truck       0.53      0.33      0.41      1000
#
#     accuracy                           0.37     10000
#    macro avg       0.39      0.37      0.35     10000
# weighted avg       0.39      0.37      0.35     10000

# %%
# Generate the classification report
report = classification_report(true_labels, predicted_labels_dropout, target_names=cifar_10_labels.values(),)

# Print the classification report
print(report)
# Out:
#               precision    recall  f1-score   support
#
#     airplane       0.40      0.49      0.44      1000
#   automobile       0.46      0.43      0.44      1000
#         bird       0.29      0.20      0.24      1000
#          cat       0.22      0.43      0.29      1000
#         deer       0.48      0.07      0.13      1000
#          dog       0.42      0.23      0.30      1000
#         frog       0.37      0.46      0.41      1000
#        horse       0.38      0.49      0.43      1000
#         ship       0.49      0.37      0.42      1000
#        truck       0.43      0.51      0.47      1000
#
#     accuracy                           0.37     10000
#    macro avg       0.39      0.37      0.36     10000
# weighted avg       0.39      0.37      0.36     10000

# %% [markdown]
# #### In multi-class classification problems, macro-average and micro-average are two commonly used methods to calculate precision, recall, and accuracy.
#
# Micro-average calculates the metrics globally by counting the total true positives, false negatives, and false positives across all classes. Micro-average is useful when you want to weight each instance or prediction equally, regardless of the class.
#
# Macro-average calculates the metrics for each class separately and then takes the average across all classes. Macro-average is useful when you want to weight each class equally, regardless of the number of instances or predictions in each class.
#
# Here's a brief explanation of the differences between micro-average and macro-average for precision, recall, and accuracy:
# Micro-average precision, recall, and accuracy are calculated by counting the total true positives, false negatives, and false positives across all classes and then calculating the precision, recall, and accuracy from those counts. Micro-average gives equal weight to each instance or prediction, regardless of the class.
#
# * Macro-average precision, recall, and accuracy are calculated by calculating the precision, recall, and accuracy for each class separately and then taking the average across all classes.
# * Macro-average gives equal weight to each class, regardless of the number of instances or predictions in each class.
