# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.layers import Dense, Normalization
import seaborn as sns

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data' 
column_names = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
                'acceleration', 'model_year', 'origin']

data = pd.read_csv(url, names=column_names,
                    na_values='?', comment='\t',
                    sep=' ', skipinitialspace=True)

# %%
data.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    model_year  origin
# 0          70       1
# 1          70       1
# 2          70       1
# 3          70       1
# 4          70       1

# %%
print(data.isna().sum())
data = data.dropna()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
data.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  model_year
# 0  18.0          8         307.0       130.0  3504.0          12.0          70
# 1  15.0          8         350.0       165.0  3693.0          11.5          70
# 2  18.0          8         318.0       150.0  3436.0          11.0          70
# 3  16.0          8         304.0       150.0  3433.0          12.0          70
# 4  17.0          8         302.0       140.0  3449.0          10.5          70

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 392 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        392 non-null    float64
#  5   acceleration  392 non-null    float64
#  6   model_year    392 non-null    int64
#  7   origin        392 non-null    int64
# dtypes: float64(5), int64(3)
# memory usage: 27.6 KB

# %%
train_dataset = data.sample(frac=0.8, random_state=0)
test_dataset = data.drop(train_dataset.index)

# %%
sns.pairplot(train_dataset[['mpg', 'cylinders', 'displacement','horsepower', 'weight', 'acceleration', 'model_year']], diag_kind='kde')
# Out:
# /Users/binilkuriachan/anaconda3/envs/ail-411-env/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
train_dataset.describe().transpose()[['mean', 'std']]
# Out:
#                      mean         std
# mpg             23.310510    7.728652
# cylinders        5.477707    1.699788
# displacement   195.318471  104.331589
# horsepower     104.869427   38.096214
# weight        2990.251592  843.898596
# acceleration    15.559236    2.789230
# model_year      75.898089    3.675642
# origin           1.573248    0.800988

# %%
train_features = train_dataset.copy()
test_features = test_dataset.copy() 

train_labels = train_features.pop('mpg')
test_labels = test_features.pop('mpg')

# %%
#Normalize
data_normalizer = Normalization(axis=1)
data_normalizer.adapt(np.array(train_features))

# %%
model = tf.keras.Sequential([
                      data_normalizer,
                      tf.keras.layers.Dense(64,  activation='relu'),
                      tf.keras.layers.Dense(32,  activation='relu'),
                      tf.keras.layers.Dense(1,  activation=None)
])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizati  (None, 7)                 15
#  on)
#
#  dense_9 (Dense)             (None, 64)                512
#
#  dense_10 (Dense)            (None, 32)                2080
#
#  dense_11 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 2640 (10.32 KB)
# Trainable params: 2625 (10.25 KB)
# Non-trainable params: 15 (64.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
history = model.fit(x=train_features,y=train_labels, epochs=100, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 2s 46ms/step - loss: 598.7834 - val_loss: 619.5065
# Epoch 2/100
# 8/8 [==============================] - 0s 6ms/step - loss: 588.9645 - val_loss: 608.0610
# Epoch 3/100
# 8/8 [==============================] - 0s 6ms/step - loss: 578.3279 - val_loss: 597.1252
# Epoch 4/100
# 8/8 [==============================] - 0s 6ms/step - loss: 568.0391 - val_loss: 585.6349
# Epoch 5/100
# 8/8 [==============================] - 0s 6ms/step - loss: 556.9459 - val_loss: 572.1325
# Epoch 6/100
# 8/8 [==============================] - 0s 6ms/step - loss: 544.0876 - val_loss: 558.2560
# Epoch 7/100
# 8/8 [==============================] - 0s 6ms/step - loss: 531.0710 - val_loss: 542.6690
# Epoch 8/100
# 8/8 [==============================] - 0s 6ms/step - loss: 516.6717 - val_loss: 526.9391
# Epoch 9/100
# 8/8 [==============================] - 0s 6ms/step - loss: 501.3387 - val_loss: 510.8784
# Epoch 10/100
# 8/8 [==============================] - 0s 6ms/step - loss: 486.8417 - val_loss: 495.6240
# Epoch 11/100
# 8/8 [==============================] - 0s 6ms/step - loss: 475.6436 - val_loss: 483.0759
# Epoch 12/100
# 8/8 [==============================] - 0s 6ms/step - loss: 464.5754 - val_loss: 474.0313
# Epoch 13/100
# 8/8 [==============================] - 0s 6ms/step - loss: 458.5755 - val_loss: 467.7525
# Epoch 14/100
# 8/8 [==============================] - 0s 6ms/step - loss: 451.8102 - val_loss: 461.5936
# Epoch 15/100
# 8/8 [==============================] - 0s 6ms/step - loss: 445.0921 - val_loss: 453.9819
# Epoch 16/100
# 8/8 [==============================] - 0s 6ms/step - loss: 437.0483 - val_loss: 445.4429
# Epoch 17/100
# 8/8 [==============================] - 0s 6ms/step - loss: 427.9655 - val_loss: 435.2197
# Epoch 18/100
# 8/8 [==============================] - 0s 6ms/step - loss: 417.6449 - val_loss: 424.0880
# Epoch 19/100
# 8/8 [==============================] - 0s 6ms/step - loss: 407.5947 - val_loss: 414.0934
# Epoch 20/100
# 8/8 [==============================] - 0s 6ms/step - loss: 398.1473 - val_loss: 404.6629
# Epoch 21/100
# 8/8 [==============================] - 0s 6ms/step - loss: 388.7990 - val_loss: 396.0398
# Epoch 22/100
# 8/8 [==============================] - 0s 6ms/step - loss: 380.5089 - val_loss: 387.3856
# Epoch 23/100
# 8/8 [==============================] - 0s 6ms/step - loss: 373.4431 - val_loss: 378.8239
# Epoch 52/100
# 8/8 [==============================] - 0s 6ms/step - loss: 127.3729 - val_loss: 129.5893
# Epoch 53/100
# 8/8 [==============================] - 0s 6ms/step - loss: 120.8997 - val_loss: 123.6088
# Epoch 54/100
# 8/8 [==============================] - 0s 6ms/step - loss: 116.6599 - val_loss: 118.4072
# Epoch 55/100
# 8/8 [==============================] - 0s 6ms/step - loss: 110.8366 - val_loss: 112.0281
# Epoch 56/100
# 8/8 [==============================] - 0s 6ms/step - loss: 106.0563 - val_loss: 107.0426
# Epoch 57/100
# 8/8 [==============================] - 0s 6ms/step - loss: 98.7165 - val_loss: 99.7111
# Epoch 58/100
# 8/8 [==============================] - 0s 6ms/step - loss: 93.7154 - val_loss: 99.6095
# Epoch 59/100
# 8/8 [==============================] - 0s 6ms/step - loss: 88.9564 - val_loss: 90.4424
# Epoch 60/100
# 8/8 [==============================] - 0s 6ms/step - loss: 83.9301 - val_loss: 80.5066
# Epoch 61/100
# 8/8 [==============================] - 0s 6ms/step - loss: 78.1934 - val_loss: 75.9342
# Epoch 62/100
# 8/8 [==============================] - 0s 6ms/step - loss: 72.6522 - val_loss: 71.6914
# Epoch 63/100
# 8/8 [==============================] - 0s 6ms/step - loss: 64.5124 - val_loss: 65.5388
# Epoch 64/100
# 8/8 [==============================] - 0s 6ms/step - loss: 61.2493 - val_loss: 61.2449
# Epoch 65/100
# 8/8 [==============================] - 0s 6ms/step - loss: 56.9151 - val_loss: 57.6493
# Epoch 66/100
# 8/8 [==============================] - 0s 6ms/step - loss: 54.0429 - val_loss: 54.6527
# Epoch 67/100
# 8/8 [==============================] - 0s 6ms/step - loss: 50.6671 - val_loss: 54.2721
# Epoch 68/100
# 8/8 [==============================] - 0s 6ms/step - loss: 49.3583 - val_loss: 51.8457
# Epoch 69/100
# 8/8 [==============================] - 0s 6ms/step - loss: 46.3886 - val_loss: 45.7925
# Epoch 70/100
# 8/8 [==============================] - 0s 6ms/step - loss: 43.4343 - val_loss: 45.9555
# Epoch 71/100
# 8/8 [==============================] - 0s 6ms/step - loss: 41.8925 - val_loss: 49.5061
# Epoch 72/100
# 8/8 [==============================] - 0s 6ms/step - loss: 40.4104 - val_loss: 44.9764
# Epoch 73/100
# 8/8 [==============================] - 0s 6ms/step - loss: 36.3590 - val_loss: 38.4080
# Epoch 74/100
# 8/8 [==============================] - 0s 6ms/step - loss: 35.3324 - val_loss: 35.5782
# Epoch 75/100
# 8/8 [==============================] - 0s 6ms/step - loss: 32.0067 - val_loss: 34.6355
# Epoch 76/100
# 8/8 [==============================] - 0s 6ms/step - loss: 31.1043 - val_loss: 31.7827
# Epoch 77/100
# 8/8 [==============================] - 0s 6ms/step - loss: 30.7736 - val_loss: 32.5861
# Epoch 78/100
# 8/8 [==============================] - 0s 6ms/step - loss: 30.3223 - val_loss: 30.7685
# Epoch 79/100
# 8/8 [==============================] - 0s 6ms/step - loss: 27.8242 - val_loss: 27.4002
# Epoch 80/100
# 8/8 [==============================] - 0s 6ms/step - loss: 26.3754 - val_loss: 36.7634
# Epoch 81/100
# 8/8 [==============================] - 0s 6ms/step - loss: 31.3904 - val_loss: 25.5237
# Epoch 82/100
# 8/8 [==============================] - 0s 6ms/step - loss: 25.5376 - val_loss: 29.3234
# Epoch 83/100
# 8/8 [==============================] - 0s 6ms/step - loss: 26.8112 - val_loss: 24.8678
# Epoch 84/100
# 8/8 [==============================] - 0s 6ms/step - loss: 25.0675 - val_loss: 29.1760
# Epoch 85/100
# 8/8 [==============================] - 0s 6ms/step - loss: 26.4420 - val_loss: 23.0599
# Epoch 86/100
# 8/8 [==============================] - 0s 6ms/step - loss: 21.6765 - val_loss: 20.5651
# Epoch 87/100
# 8/8 [==============================] - 0s 6ms/step - loss: 21.1165 - val_loss: 19.8549
# Epoch 88/100
# 8/8 [==============================] - 0s 6ms/step - loss: 20.3427 - val_loss: 20.2946
# Epoch 89/100
# 8/8 [==============================] - 0s 6ms/step - loss: 19.8866 - val_loss: 21.5477
# Epoch 90/100
# 8/8 [==============================] - 0s 6ms/step - loss: 19.8468 - val_loss: 19.1466
# Epoch 91/100
# 8/8 [==============================] - 0s 6ms/step - loss: 23.4840 - val_loss: 20.5305
# Epoch 92/100
# 8/8 [==============================] - 0s 6ms/step - loss: 19.1042 - val_loss: 18.2266
# Epoch 93/100
# 8/8 [==============================] - 0s 6ms/step - loss: 19.7676 - val_loss: 19.1990
# Epoch 94/100
# 8/8 [==============================] - 0s 6ms/step - loss: 17.5351 - val_loss: 17.3327
# Epoch 95/100
# 8/8 [==============================] - 0s 6ms/step - loss: 23.8160 - val_loss: 36.7564
# Epoch 96/100
# 8/8 [==============================] - 0s 6ms/step - loss: 22.7798 - val_loss: 17.2348
# Epoch 97/100
# 8/8 [==============================] - 0s 6ms/step - loss: 18.0945 - val_loss: 16.7146
# Epoch 98/100
# 8/8 [==============================] - 0s 6ms/step - loss: 16.7058 - val_loss: 16.7018
# Epoch 99/100
# 8/8 [==============================] - 0s 6ms/step - loss: 17.9151 - val_loss: 20.6008
# Epoch 100/100
# 8/8 [==============================] - 0s 6ms/step - loss: 19.1994 - val_loss: 15.6509

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Error [MPG]')
plt.legend()
plt.grid(True)

# %%
y_pred = model.predict(test_features).flatten()
a = plt.axes(aspect='equal')
plt.scatter(test_labels, y_pred)
plt.xlabel('True Values [MPG]')
plt.ylabel('Predictions [MPG]')
lims = [0, 50]
plt.xlim(lims)
plt.ylim(lims)
plt.plot(lims, lims)
# Out:
# 3/3 [==============================] - 0s 76ms/step

# %%
error = y_pred - test_labels
plt.hist(error, bins=30)
plt.xlabel('Prediction Error [MPG]')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')
