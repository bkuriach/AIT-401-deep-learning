# %%
import os
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
import tensorflow_datasets as tfds
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras import (
    models,
    layers,
) 
from matplotlib import pyplot as plt
import numpy as np
import random
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt

# %%
cifar_10_labels = {
    0: 'airplane',
    1: 'automobile',
    2: 'bird',
    3: 'cat',
    4: 'deer',
    5: 'dog',
    6: 'frog',
    7: 'horse',
    8: 'ship',
    9: 'truck'
    }

model_directory = 'models'

# %%
class RandomIntegers():
    def __init__(self):
        pass
    
    def generate(self, n, length):
        # Generate n unique random integers between 0 and length
        random_integers = random.sample(range(length), n)
        
        return random_integers

# %% [markdown]
# #### CIFAR-10
# ###### CIFAR-10 dataset consists of 60000 32×32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.

# %%
# Load the CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train/255
x_test = x_test/255

# %% [markdown]
# ### Plot dataset

# %%
def display_images():
    random_integers = RandomIntegers().generate(9, len(x_train))
    plt.figure(figsize=(6, 8))
    counter = 0
    for i in random_integers:
        # define subplot
        plt.subplot(330 + 1 + counter)
        counter += 1
        # plot raw pixel data
        plt.imshow(x_train[i])
        plt.title(cifar_10_labels[y_train[i][0]])
    # show the figure
    plt.show()
display_images()

# %% [markdown]
# ### Build Model

# %%
model = tensorflow.keras.models.Sequential([
    tensorflow.keras.layers.Flatten(input_shape=(32, 32, 3)),
    tensorflow.keras.layers.Dense(128, activation='relu'),
    # tensorflow.keras.layers.Dense(32, activation='relu'),
    tensorflow.keras.layers.Dense(10, activation='softmax')
])

# %% [markdown]
# ### Compiling the model

# %%
# model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.compile(
    optimizer=tf.keras.optimizers.Adam(0.001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.

# %% [markdown]
# #### Model Training

# %%
history = model.fit(x_train,
                    y_train,
                    epochs=25,
                    batch_size=512,
                    validation_data=(x_test, y_test))
# Out:
# Epoch 1/25
# 98/98 [==============================] - 2s 16ms/step - loss: 2.9175 - sparse_categorical_accuracy: 0.1954 - val_loss: 2.0459 - val_sparse_categorical_accuracy: 0.2560
# Epoch 2/25
# 98/98 [==============================] - 1s 8ms/step - loss: 2.0104 - sparse_categorical_accuracy: 0.2742 - val_loss: 1.9696 - val_sparse_categorical_accuracy: 0.2871
# Epoch 3/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.9374 - sparse_categorical_accuracy: 0.3072 - val_loss: 1.9152 - val_sparse_categorical_accuracy: 0.3123
# Epoch 4/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.8912 - sparse_categorical_accuracy: 0.3272 - val_loss: 1.8847 - val_sparse_categorical_accuracy: 0.3280
# Epoch 5/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.8607 - sparse_categorical_accuracy: 0.3399 - val_loss: 1.8523 - val_sparse_categorical_accuracy: 0.3514
# Epoch 6/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.8332 - sparse_categorical_accuracy: 0.3551 - val_loss: 1.8310 - val_sparse_categorical_accuracy: 0.3542
# Epoch 7/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.8160 - sparse_categorical_accuracy: 0.3639 - val_loss: 1.8463 - val_sparse_categorical_accuracy: 0.3411
# Epoch 8/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.8114 - sparse_categorical_accuracy: 0.3660 - val_loss: 1.8057 - val_sparse_categorical_accuracy: 0.3635
# Epoch 9/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.8020 - sparse_categorical_accuracy: 0.3692 - val_loss: 1.7953 - val_sparse_categorical_accuracy: 0.3688
# Epoch 10/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7903 - sparse_categorical_accuracy: 0.3750 - val_loss: 1.8015 - val_sparse_categorical_accuracy: 0.3668
# Epoch 11/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7909 - sparse_categorical_accuracy: 0.3746 - val_loss: 1.7797 - val_sparse_categorical_accuracy: 0.3819
# Epoch 12/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7784 - sparse_categorical_accuracy: 0.3822 - val_loss: 1.7765 - val_sparse_categorical_accuracy: 0.3801
# Epoch 13/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7819 - sparse_categorical_accuracy: 0.3800 - val_loss: 1.7823 - val_sparse_categorical_accuracy: 0.3752
# Epoch 14/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7737 - sparse_categorical_accuracy: 0.3847 - val_loss: 1.8110 - val_sparse_categorical_accuracy: 0.3643
# Epoch 15/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7718 - sparse_categorical_accuracy: 0.3843 - val_loss: 1.7746 - val_sparse_categorical_accuracy: 0.3792
# Epoch 16/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7688 - sparse_categorical_accuracy: 0.3834 - val_loss: 1.7753 - val_sparse_categorical_accuracy: 0.3821
# Epoch 17/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7647 - sparse_categorical_accuracy: 0.3865 - val_loss: 1.7903 - val_sparse_categorical_accuracy: 0.3758
# Epoch 18/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7700 - sparse_categorical_accuracy: 0.3835 - val_loss: 1.7905 - val_sparse_categorical_accuracy: 0.3768
# Epoch 19/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7627 - sparse_categorical_accuracy: 0.3877 - val_loss: 1.7753 - val_sparse_categorical_accuracy: 0.3814
# Epoch 20/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7541 - sparse_categorical_accuracy: 0.3911 - val_loss: 1.7736 - val_sparse_categorical_accuracy: 0.3817
# Epoch 21/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7597 - sparse_categorical_accuracy: 0.3881 - val_loss: 1.7638 - val_sparse_categorical_accuracy: 0.3824
# Epoch 22/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7637 - sparse_categorical_accuracy: 0.3829 - val_loss: 1.7761 - val_sparse_categorical_accuracy: 0.3823
# Epoch 23/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7596 - sparse_categorical_accuracy: 0.3867 - val_loss: 1.8074 - val_sparse_categorical_accuracy: 0.3598
# Epoch 24/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7548 - sparse_categorical_accuracy: 0.3901 - val_loss: 1.7652 - val_sparse_categorical_accuracy: 0.3819
# Epoch 25/25
# 98/98 [==============================] - 1s 7ms/step - loss: 1.7573 - sparse_categorical_accuracy: 0.3882 - val_loss: 1.7776 - val_sparse_categorical_accuracy: 0.3826

# %% [markdown]
# #### Plot Accuracy

# %%
# Plot the accuracy from the training history
plt.plot(history.history['sparse_categorical_accuracy'])
plt.plot(history.history['val_sparse_categorical_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot the accuracy from the training history
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# #### Save model

# %%
if not os.path.exists(model_directory):
    os.makedirs(model_directory)
model_path = os.path.join(model_directory,"model_nn.h5")
model.save(model_path)

# %% [markdown]
# #### Load Model

# %%
# Load the saved model from a file
loaded_model = tf.keras.models.load_model(model_path)
loaded_model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_4 (Flatten)         (None, 3072)              0
#
#  dense_12 (Dense)            (None, 128)               393344
#
#  dense_13 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 394634 (1.51 MB)
# Trainable params: 394634 (1.51 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #### Predict

# %%
# Get the true labels and predicted labels for the test dataset
true_labels = np.concatenate([y for x, y in zip(x_test,y_test)], axis=0)
predicted_labels = np.argmax(model.predict(x_test), axis=-1)
# Out:
# 313/313 [==============================] - 1s 1ms/step

# %% [markdown]
# #### Confusion Matrix

# %%
# Generate the confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)

# Plot the confusion matrix
plt.imshow(cm, cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.xticks(np.arange(10))
plt.yticks(np.arange(10))
plt.show()

# %% [markdown]
# #### Classification Report

# %%
# Generate the classification report
report = classification_report(true_labels, predicted_labels, target_names=cifar_10_labels.values(),)

# Print the classification report
print(report)
# Out:
#               precision    recall  f1-score   support
#
#     airplane       0.42      0.47      0.44      1000
#   automobile       0.48      0.49      0.48      1000
#         bird       0.23      0.40      0.30      1000
#          cat       0.34      0.19      0.24      1000
#         deer       0.49      0.07      0.13      1000
#          dog       0.35      0.32      0.34      1000
#         frog       0.36      0.56      0.44      1000
#        horse       0.39      0.51      0.44      1000
#         ship       0.50      0.41      0.45      1000
#        truck       0.48      0.40      0.44      1000
#
#     accuracy                           0.38     10000
#    macro avg       0.40      0.38      0.37     10000
# weighted avg       0.40      0.38      0.37     10000

# %% [markdown]
# #### In multi-class classification problems, macro-average and micro-average are two commonly used methods to calculate precision, recall, and accuracy.
#
# Micro-average calculates the metrics globally by counting the total true positives, false negatives, and false positives across all classes. Micro-average is useful when you want to weight each instance or prediction equally, regardless of the class.
#
# Macro-average calculates the metrics for each class separately and then takes the average across all classes. Macro-average is useful when you want to weight each class equally, regardless of the number of instances or predictions in each class.
#
# Here's a brief explanation of the differences between micro-average and macro-average for precision, recall, and accuracy:
# Micro-average precision, recall, and accuracy are calculated by counting the total true positives, false negatives, and false positives across all classes and then calculating the precision, recall, and accuracy from those counts. Micro-average gives equal weight to each instance or prediction, regardless of the class.
#
# * Macro-average precision, recall, and accuracy are calculated by calculating the precision, recall, and accuracy for each class separately and then taking the average across all classes.
# * Macro-average gives equal weight to each class, regardless of the number of instances or predictions in each class.
